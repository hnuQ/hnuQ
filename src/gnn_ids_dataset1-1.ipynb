# %%
# %load_ext autoreload
# %autoreload 2
import os
import time
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn

from ag_utils import Corpus
from ag_utils import parse_ag_file
from ag_utils import parse_node_properties

from synthetic_data import gene_dataset

from models import NN, GCN, GAT, GCN_EW
from model_utils import train, predict_prob, evaluate_performance

# %%
# parse attack graph file generated by MulVAL tool
attack_graph_path = '../mulval_attack_graph/AttackGraph.dot'
nodes, edges, node_properties = parse_ag_file(attack_graph_path)
node_dict = parse_node_properties(nodes, node_properties)

# save node label into corpus object
corpus = Corpus(node_dict)
num_tokens = corpus.get_num_tokens()
node_features = corpus.get_node_features()
node_types = corpus.get_node_types()
vocab_size = len(corpus.dictionary)
print('vocab_size: ', vocab_size)
print('num_tokens: ', num_tokens)
print('node_features shape: ', node_features.shape)
# Out:
# vocab_size:  57
# num_tokens:  118
# node_features shape:  torch.Size([26, 57])

# %%
# statistics of the encoded attack graph
num_nodes = len(nodes)
print('num_nodes: ', num_nodes)

num_node_features = node_features.shape[1]
print('num_node_features: ', num_node_features)

num_edges = len(edges)
print('num_edges: ', num_edges)

action_nodes = corpus.get_action_nodes()
action_node_idx = list(action_nodes.keys())
num_action_nodes = len(action_node_idx)
print('action_node_idx: ', action_node_idx)
print('num_action_nodes: ', num_action_nodes)

# var 'action_mask' is for representing the attack scenarios in attack graph (i.e., the privilege nodes)
action_mask = action_node_idx
# Out:
# num_nodes:  26
# num_node_features:  57
# num_edges:  26
# action_node_idx:  [0, 2, 4, 7, 9, 12, 14]
# num_action_nodes:  7

# %%
# adj matrix and edge index
adj_matrix = torch.zeros(len(nodes), len(nodes))

for edge in edges:
    source_node, target_node = edge
    source_index = nodes.index(source_node)
    target_index = nodes.index(target_node)
    adj_matrix[source_index][target_index] = 1

edge_index = adj_matrix.nonzero().t().contiguous()

assert edge_index.shape[0]==2

# %%
# prepare Dataset 1
num_benign = 1500
num_malic = 500
rt_meas_dim = 78
sample_method = 'synthetic'

X, Y = gene_dataset(num_benign, num_malic, num_nodes, action_nodes, rt_meas_dim)
num_samples = X.shape[0]

# rescale the data with min-max scaler
scaler = MinMaxScaler(feature_range=(0, 1))
X = scaler.fit_transform(X.view(-1, rt_meas_dim))
X = torch.from_numpy(X).float().view(num_samples, num_nodes, rt_meas_dim)

# associate node features in attack graph with real-time measurements
node_feat_ts = torch.stack([node_features for _ in range(len(X))], dim=0)
X = torch.cat((node_feat_ts, X), dim=2)

# split the data into training, validation and test set
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42, stratify=Y)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.25, random_state=42, stratify=Y_train)
print(X_train.shape, Y_train.shape, X_val.shape, Y_val.shape, X_test.shape, Y_test.shape)
# Out:
# torch.Size([3000, 26, 135]) torch.Size([3000, 7]) torch.Size([1000, 26, 135]) torch.Size([1000, 7]) torch.Size([1000, 26, 135]) torch.Size([1000, 7])

# %%
# load Dataset 1 used in the paper
data_path = '../datasets/synt/'
X_train = torch.load(data_path+'X_train-{}.pth'.format(sample_method))
X_val   = torch.load(data_path+'X_val-{}.pth'.format(sample_method))
X_test  = torch.load(data_path+'X_test-{}.pth'.format(sample_method))
Y_train = torch.load(data_path+'Y_train-{}.pth'.format(sample_method))
Y_val   = torch.load(data_path+'Y_val-{}.pth'.format(sample_method))
Y_test  = torch.load(data_path+'Y_test-{}.pth'.format(sample_method))
print(X_train.shape, Y_train.shape, X_val.shape, Y_val.shape, X_test.shape, Y_test.shape)
# Out:
# torch.Size([3000, 26, 135]) torch.Size([3000, 7]) torch.Size([1000, 26, 135]) torch.Size([1000, 7]) torch.Size([1000, 26, 135]) torch.Size([1000, 7])

# %%
# hyperparameters for training
in_dim = X_train.shape[-1]
hidden_dim = 20
out_dim = 1
lr = 0.001
device = 'cpu'
# model initialization
models = {}
model_NN = NN(rt_meas_dim, hidden_dim, out_dim)
model_GCN = GCN(in_dim, hidden_dim, out_dim)
model_GCN_EW = GCN_EW(in_dim, hidden_dim, out_dim, edge_index)
model_GAT = GAT(hidden_channels=hidden_dim, heads=4, in_dim=in_dim, out_dim=out_dim)

models['NN'] = model_NN
models['GCN'] = model_GCN
models['GCN-EW'] = model_GCN_EW
models['GAT'] = model_GAT


for name, model in models.items():
    model.name = name
    model.action_mask = action_mask
    num_epochs = 200 # early stop when overfitting observed

    print(f'{model.name} start training...')
    time_start = time.time()
    print('model: ', model) 
    train(model, lr, num_epochs, X_train, Y_train, X_val, Y_val, edge_index, rt_meas_dim, device)       
    time_end = time.time()
    print('time cost: ', time_end - time_start)  
    print(f'{model.name} training finished!')

    print(f'{model.name} accuracy on training set: {model.stat["acc_train"][-1]}')
    print(f'{model.name} accuracy on validation set: {model.stat["acc_val"][-1]}')
# Out:
# NN start training...
# model:  NN(
#   (lin1): Linear(in_features=78, out_features=20, bias=True)
#   (lin2): Linear(in_features=20, out_features=20, bias=True)
#   (out_layer): Linear(in_features=20, out_features=1, bias=True)
# )
# Epoch: 010, Training Loss: 0.8956, Traning Accuracy: 0.7891, Validation Loss: 0.9104, Validation Accuracy: 0.7857
# Epoch: 020, Training Loss: 0.8990, Traning Accuracy: 0.7978, Validation Loss: 0.9148, Validation Accuracy: 0.7926
# Epoch: 030, Training Loss: 0.8899, Traning Accuracy: 0.7854, Validation Loss: 0.9067, Validation Accuracy: 0.7840
# Epoch: 040, Training Loss: 0.8829, Traning Accuracy: 0.7776, Validation Loss: 0.9009, Validation Accuracy: 0.7784
# Epoch: 050, Training Loss: 0.8753, Traning Accuracy: 0.7656, Validation Loss: 0.8960, Validation Accuracy: 0.7641
# Epoch: 060, Training Loss: 0.8717, Traning Accuracy: 0.7627, Validation Loss: 0.8954, Validation Accuracy: 0.7601
# Epoch: 070, Training Loss: 0.8644, Traning Accuracy: 0.7599, Validation Loss: 0.8930, Validation Accuracy: 0.7576
# Epoch: 080, Training Loss: 0.8603, Traning Accuracy: 0.7609, Validation Loss: 0.8927, Validation Accuracy: 0.7556
# Epoch: 090, Training Loss: 0.8521, Traning Accuracy: 0.7618, Validation Loss: 0.8903, Validation Accuracy: 0.7583
# Epoch: 100, Training Loss: 0.8443, Traning Accuracy: 0.7615, Validation Loss: 0.8885, Validation Accuracy: 0.7543
# Epoch: 110, Training Loss: 0.8382, Traning Accuracy: 0.7677, Validation Loss: 0.8904, Validation Accuracy: 0.7587
# Epoch: 120, Training Loss: 0.8302, Traning Accuracy: 0.7710, Validation Loss: 0.8905, Validation Accuracy: 0.7621
# Epoch: 130, Training Loss: 0.8169, Traning Accuracy: 0.7727, Validation Loss: 0.8850, Validation Accuracy: 0.7637
# Epoch: 140, Training Loss: 0.7622, Traning Accuracy: 0.8011, Validation Loss: 0.8422, Validation Accuracy: 0.7849
# Epoch: 150, Training Loss: 0.6813, Traning Accuracy: 0.8388, Validation Loss: 0.7588, Validation Accuracy: 0.8257
# Epoch: 160, Training Loss: 0.6617, Traning Accuracy: 0.8472, Validation Loss: 0.7452, Validation Accuracy: 0.8343
# Epoch: 170, Training Loss: 0.6515, Traning Accuracy: 0.8512, Validation Loss: 0.7454, Validation Accuracy: 0.8367
# Epoch: 180, Training Loss: 0.6432, Traning Accuracy: 0.8572, Validation Loss: 0.7414, Validation Accuracy: 0.8423
# Epoch: 190, Training Loss: 0.6266, Traning Accuracy: 0.8537, Validation Loss: 0.7253, Validation Accuracy: 0.8393
# Epoch: 200, Training Loss: 0.6049, Traning Accuracy: 0.8565, Validation Loss: 0.7033, Validation Accuracy: 0.8431
# time cost:  288.9706087112427
# NN training finished!
# NN accuracy on training set: 0.8565238095238096
# NN accuracy on validation set: 0.8431428571428572
# GCN start training...
# model:  GCN(
#   (conv1): GCNConv(135, 20)
#   (conv2): GCNConv(20, 20)
#   (classifier): Linear(in_features=20, out_features=1, bias=True)
# )
# Epoch: 010, Training Loss: 0.8567, Traning Accuracy: 0.8180, Validation Loss: 0.8889, Validation Accuracy: 0.8161
# Epoch: 020, Training Loss: 0.6391, Traning Accuracy: 0.8331, Validation Loss: 0.6701, Validation Accuracy: 0.8314
# Epoch: 030, Training Loss: 0.5165, Traning Accuracy: 0.8724, Validation Loss: 0.5570, Validation Accuracy: 0.8699
# Epoch: 040, Training Loss: 0.4330, Traning Accuracy: 0.9030, Validation Loss: 0.4896, Validation Accuracy: 0.9003
# Epoch: 050, Training Loss: 0.3813, Traning Accuracy: 0.9199, Validation Loss: 0.4490, Validation Accuracy: 0.9169
# Epoch: 060, Training Loss: 0.3405, Traning Accuracy: 0.9339, Validation Loss: 0.4168, Validation Accuracy: 0.9283
# Epoch: 070, Training Loss: 0.3080, Traning Accuracy: 0.9425, Validation Loss: 0.3952, Validation Accuracy: 0.9371
# Epoch: 080, Training Loss: 0.2851, Traning Accuracy: 0.9494, Validation Loss: 0.3807, Validation Accuracy: 0.9409
# Epoch: 090, Training Loss: 0.2664, Traning Accuracy: 0.9527, Validation Loss: 0.3681, Validation Accuracy: 0.9451
# Epoch: 100, Training Loss: 0.2490, Traning Accuracy: 0.9553, Validation Loss: 0.3559, Validation Accuracy: 0.9474
# Epoch: 110, Training Loss: 0.2342, Traning Accuracy: 0.9572, Validation Loss: 0.3464, Validation Accuracy: 0.9501
# Epoch: 120, Training Loss: 0.2228, Traning Accuracy: 0.9580, Validation Loss: 0.3396, Validation Accuracy: 0.9501
# Epoch: 130, Training Loss: 0.2142, Traning Accuracy: 0.9594, Validation Loss: 0.3371, Validation Accuracy: 0.9523
# Epoch: 140, Training Loss: 0.2066, Traning Accuracy: 0.9589, Validation Loss: 0.3324, Validation Accuracy: 0.9511
# Epoch: 150, Training Loss: 0.2010, Traning Accuracy: 0.9584, Validation Loss: 0.3304, Validation Accuracy: 0.9497
# Epoch: 160, Training Loss: 0.1943, Traning Accuracy: 0.9571, Validation Loss: 0.3227, Validation Accuracy: 0.9484
# Epoch: 170, Training Loss: 0.1925, Traning Accuracy: 0.9565, Validation Loss: 0.3261, Validation Accuracy: 0.9489
# Epoch: 180, Training Loss: 0.1885, Traning Accuracy: 0.9587, Validation Loss: 0.3278, Validation Accuracy: 0.9491
# Epoch: 190, Training Loss: 0.1865, Traning Accuracy: 0.9575, Validation Loss: 0.3297, Validation Accuracy: 0.9487
# Epoch: 200, Training Loss: 0.1846, Traning Accuracy: 0.9567, Validation Loss: 0.3290, Validation Accuracy: 0.9480
# time cost:  113.02644395828247
# GCN training finished!
# GCN accuracy on training set: 0.9567142857142857
# GCN accuracy on validation set: 0.948
# GCN-EW start training...
# model:  GCN_EW(
#   (conv1): GCNConv(135, 20)
#   (conv2): GCNConv(20, 20)
#   (classifier): Linear(in_features=20, out_features=1, bias=True)
# )
# Epoch: 010, Training Loss: 0.7291, Traning Accuracy: 0.8531, Validation Loss: 0.7562, Validation Accuracy: 0.8566
# Epoch: 020, Training Loss: 0.4935, Traning Accuracy: 0.9003, Validation Loss: 0.5380, Validation Accuracy: 0.9020
# Epoch: 030, Training Loss: 0.3642, Traning Accuracy: 0.9279, Validation Loss: 0.4269, Validation Accuracy: 0.9276
# Epoch: 040, Training Loss: 0.3074, Traning Accuracy: 0.9393, Validation Loss: 0.3830, Validation Accuracy: 0.9366
# Epoch: 050, Training Loss: 0.2712, Traning Accuracy: 0.9476, Validation Loss: 0.3559, Validation Accuracy: 0.9431
# Epoch: 060, Training Loss: 0.2460, Traning Accuracy: 0.9544, Validation Loss: 0.3429, Validation Accuracy: 0.9500
# Epoch: 070, Training Loss: 0.2250, Traning Accuracy: 0.9593, Validation Loss: 0.3289, Validation Accuracy: 0.9524
# Epoch: 080, Training Loss: 0.2116, Traning Accuracy: 0.9627, Validation Loss: 0.3232, Validation Accuracy: 0.9553
# Epoch: 090, Training Loss: 0.2040, Traning Accuracy: 0.9647, Validation Loss: 0.3264, Validation Accuracy: 0.9563
# Epoch: 100, Training Loss: 0.1968, Traning Accuracy: 0.9662, Validation Loss: 0.3270, Validation Accuracy: 0.9570
# Epoch: 110, Training Loss: 0.1907, Traning Accuracy: 0.9670, Validation Loss: 0.3295, Validation Accuracy: 0.9580
# Epoch: 120, Training Loss: 0.1813, Traning Accuracy: 0.9675, Validation Loss: 0.3207, Validation Accuracy: 0.9576
# Epoch: 130, Training Loss: 0.1762, Traning Accuracy: 0.9683, Validation Loss: 0.3242, Validation Accuracy: 0.9580
# Epoch: 140, Training Loss: 0.1674, Traning Accuracy: 0.9674, Validation Loss: 0.3150, Validation Accuracy: 0.9583
# Epoch: 150, Training Loss: 0.1635, Traning Accuracy: 0.9679, Validation Loss: 0.3169, Validation Accuracy: 0.9590
# Epoch: 160, Training Loss: 0.1564, Traning Accuracy: 0.9678, Validation Loss: 0.3057, Validation Accuracy: 0.9586
# Epoch: 170, Training Loss: 0.1544, Traning Accuracy: 0.9683, Validation Loss: 0.3051, Validation Accuracy: 0.9579
# Epoch: 180, Training Loss: 0.1504, Traning Accuracy: 0.9678, Validation Loss: 0.3042, Validation Accuracy: 0.9566
# Epoch: 190, Training Loss: 0.1488, Traning Accuracy: 0.9700, Validation Loss: 0.3142, Validation Accuracy: 0.9581
# Epoch: 200, Training Loss: 0.1439, Traning Accuracy: 0.9664, Validation Loss: 0.2968, Validation Accuracy: 0.9567
# time cost:  137.37738919258118
# GCN-EW training finished!
# GCN-EW accuracy on training set: 0.9663809523809523
# GCN-EW accuracy on validation set: 0.9567142857142857
# GAT start training...
# model:  GAT(
#   (conv1): GATConv(135, 20, heads=4)
#   (conv2): GATConv(80, 20, heads=4)
#   (classifier): Linear(in_features=80, out_features=1, bias=True)
# )
# Epoch: 010, Training Loss: 0.2526, Traning Accuracy: 0.9224, Validation Loss: 0.3046, Validation Accuracy: 0.9173
# Epoch: 020, Training Loss: 0.2096, Traning Accuracy: 0.9357, Validation Loss: 0.2970, Validation Accuracy: 0.9317
# Epoch: 030, Training Loss: 0.1570, Traning Accuracy: 0.9684, Validation Loss: 0.3841, Validation Accuracy: 0.9580
# Epoch: 040, Training Loss: 0.1307, Traning Accuracy: 0.9679, Validation Loss: 0.2898, Validation Accuracy: 0.9584
# Epoch: 050, Training Loss: 0.1762, Traning Accuracy: 0.9805, Validation Loss: 0.4816, Validation Accuracy: 0.9686
# Epoch: 060, Training Loss: 0.1364, Traning Accuracy: 0.9764, Validation Loss: 0.5574, Validation Accuracy: 0.9639
# Epoch: 070, Training Loss: 0.1519, Traning Accuracy: 0.9628, Validation Loss: 0.5550, Validation Accuracy: 0.9501
# Epoch: 080, Training Loss: 0.1498, Traning Accuracy: 0.9660, Validation Loss: 0.6125, Validation Accuracy: 0.9526
# Epoch: 090, Training Loss: 0.1386, Traning Accuracy: 0.9696, Validation Loss: 0.6835, Validation Accuracy: 0.9556
# Epoch: 100, Training Loss: 0.0797, Traning Accuracy: 0.9786, Validation Loss: 0.5276, Validation Accuracy: 0.9640
# Epoch: 110, Training Loss: 0.1103, Traning Accuracy: 0.9792, Validation Loss: 0.7685, Validation Accuracy: 0.9643
# Epoch: 120, Training Loss: 0.0862, Traning Accuracy: 0.9893, Validation Loss: 0.8347, Validation Accuracy: 0.9697
# Epoch: 130, Training Loss: 0.0882, Traning Accuracy: 0.9859, Validation Loss: 0.8375, Validation Accuracy: 0.9654
# Epoch: 140, Training Loss: 0.0834, Traning Accuracy: 0.9869, Validation Loss: 0.8019, Validation Accuracy: 0.9656
# Epoch: 150, Training Loss: 0.1077, Traning Accuracy: 0.9721, Validation Loss: 0.6561, Validation Accuracy: 0.9579
# Epoch: 160, Training Loss: 0.0560, Traning Accuracy: 0.9834, Validation Loss: 0.6223, Validation Accuracy: 0.9643
# Epoch: 170, Training Loss: 0.0350, Traning Accuracy: 0.9897, Validation Loss: 0.7675, Validation Accuracy: 0.9676
# Epoch: 180, Training Loss: 0.0334, Traning Accuracy: 0.9918, Validation Loss: 0.7824, Validation Accuracy: 0.9679
# Epoch: 190, Training Loss: 0.0377, Traning Accuracy: 0.9913, Validation Loss: 0.7976, Validation Accuracy: 0.9690
# Epoch: 200, Training Loss: 0.0335, Traning Accuracy: 0.9960, Validation Loss: 1.1411, Validation Accuracy: 0.9717
# time cost:  2785.3537633419037
# GAT training finished!
# GAT accuracy on training set: 0.9960476190476191
# GAT accuracy on validation set: 0.9717142857142858

# %%
# plot the roc curve
from sklearn.metrics import roc_curve, auc
fig, ax = plt.subplots(figsize=(5, 5))
for name, model in models.items():
    prob = predict_prob(model, X_test, edge_index)
    y_probs = prob.view(-1, 2)

    fpr, tpr, thresholds = roc_curve(Y_test.view(-1), y_probs[:, 1])
    roc_auc = auc(fpr, tpr)

    ax.plot(fpr, tpr, label='{} (AUC = {:.4f})'.format(model.name, roc_auc))
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_title('Receiver Operating Characteristic (ROC) Curve')
    ax.legend(loc="lower right")
ax.grid()
plt.show()

# %%
# performance evaluation
metrics = evaluate_performance(models, X_test, Y_test, edge_index, device)
df = pd.DataFrame(metrics)
print(df)
# Out:
#     model    TN   FP   FN   TP precision  recall      f1     auc     fpr  \
# 0      NN  5357  943  149  551    0.6709  0.8187  0.7049  0.9018  0.1497
# 1     GCN  5971  329   48  652    0.8283  0.9396  0.8726  0.9839  0.0522
# 2  GCN-EW  6054  246   45  655    0.8598  0.9483  0.8974  0.9880  0.0390
# 3     GAT  6213   87  104  596    0.9281  0.9188  0.9234  0.9859  0.0138
#
#       fnr loss_train loss_val acc_train acc_val accuracy
# 0  0.2129     0.6049   0.7033    0.8565  0.8431   0.8440
# 1  0.0686     0.1846   0.3290    0.9567  0.9480   0.9461
# 2  0.0643     0.1439   0.2968    0.9664  0.9567   0.9584
# 3  0.1486     0.0335   1.1411    0.9960  0.9717   0.9727

# %%
# plot the TP, FP, TN, FN
fig, axs = plt.subplots(2, 2, figsize=(5, 5))
axs = axs.ravel()

bar_width = 0.5
labels = ['TN', 'FP', 'FN', 'TP']

for i, label in enumerate(labels):
    for j, name in enumerate(models):
        rects = axs[i].bar(j, metrics[j][label], width=bar_width, label=name)
    axs[i].set_xticks(np.arange(len(models)))
    axs[i].set_xticklabels(models.keys())
    for tick in axs[i].xaxis.get_major_ticks():
        tick.label1.set_fontsize(10)
    axs[i].set_title(label)

handles, labels = axs[0].get_legend_handles_labels()

plt.tight_layout()
plt.show()

# %%
# robustness evaluation
for i in range(Y_test.shape[0]):
    for j in range(len(action_mask)):
        if Y_test[i, j] == 1:
            for k in range(rt_meas_dim):
                if True:
                    X_test[i, action_mask[j],-rt_meas_dim+k] -= torch.normal(mean=0.0, std=0.05, size=(1,)).item()

metrics = evaluate_performance(models, X_test, Y_test, edge_index, device)
df = pd.DataFrame(metrics)
print(df)

# %%
from torch_geometric.data import Data
from torch_geometric.explain import GNNExplainer, Explainer

# individual case analysis
found = False
while not found:
    indi_case_id = torch.randint(0, X_test.shape[0], (1,)).item()
    y_true = Y_test[indi_case_id]
    if y_true.sum() != 0:
        found = True
        print('indi_case_id: ', indi_case_id)

indi_case_x = X_test[indi_case_id]
indi_case_x = indi_case_x.unsqueeze(0)

# %%
# Explainability visualization
model_to_explain = model_GCN_EW
model_to_explain.eval()
if model.name in ['GAT']:
    indi_case_x = indi_case_x.view(-1, in_dim)
prob_ts = torch.sigmoid(model_to_explain(indi_case_x, edge_index))[action_mask]
print('model prob_ts: \n', prob_ts)
print('y_true: ', y_true)

data = Data(x=X_test[indi_case_id], edge_index=edge_index)

explainer = Explainer(
    model=model_to_explain,
    algorithm=GNNExplainer(epochs=200),
    explanation_type='model',
    node_mask_type='attributes',
    edge_mask_type='object',
    model_config=dict(
        mode='binary_classification',
        task_level='node',
        return_type='raw',
    ),
)

compromised_node = action_node_idx[np.where(y_true==1)[0].item()]
explanation = explainer(data.x, data.edge_index, index=compromised_node)

explanation.visualize_feature_importance(top_k=10)
explanation.visualize_graph()
